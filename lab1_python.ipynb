# %%
#Лабораторная работа 1
#Айтиев Д.С.
print("Hello, World!")

# %%
import time
import random

#Ввод
def enter():
#    m = int(input('m='))
#    n = int(input('n='))
#    min_lim = int(input('min='))
#    max_lim = int(input('max='))
    m = 50
    n = 50
    min_lim = -250
    max_lim = 1001
    array = [[random.randint(min_lim, max_lim) for j in range(n)] for i in range(m)]
    print('Matrix:')
    for i in range(m):
        print(array[i])
    return array
# Out:
# Hello, World!

# %%
#Вывод
def out(array):
    print("Sort Matrix")
    for i in range(len(array)):
        print(array[i])
    return array

# %%
def vstavka(array):
    for i in range(len(array)):
        for j in range(1, len(array[i])):
            key = array[i][j]
            k = j - 1
            while k>=0 and key < array[i][k]:
                array[i][k+1] = array[i][k]
                k -= 1
            array[i][k+1] = key
    return array

# %%
def vibor(array):
    for i in range(len(array)):
        for j in range(len(array[i]) - 1):
            min = j
            for h in range(j + 1, len(array[i])):
                if (array[i][h] < array[i][min]):
                    min = h
            temp = array[i][j]
            array[i][j] = array[i][min]
            array[i][min] = temp
    return array

# %%
def obmen(array):
    length = len(array)
    k = 1
    for k in range(len(array)):
        for i in range(len(array[k])):
            if (len(array) == len(array[k])):
                for j in range(0, length-i-1):
                    if array[k][j] > array[k][j+1]:
                        temp = array[k][j]
                        array[k][j] = array[k][j+1]
                        array[k][j+1] = temp
            else:
                for j in range(0, length-i):
                    if array[k][j] > array[k][j+1]:
                        temp = array[k][j]
                        array[k][j] = array[k][j+1]
                        array[k][j+1] = temp
    return array

# %%
def shella(array):
    for i in range(len(array)):
        d=int(len(array[i])/2)
        while d>0:
            for j in range(len(array[i])):
                for h in range(int(j+d),len(array[i]),d):
                    if array[i][j]>array[i][h]:
                        temp=array[i][j]
                        array[i][j]=array[i][h]
                        array[i][h]=temp
            d=int(d/2)
    return array

# %%
def TournamentSort(array):
    for i in range(len(array)):
        tournamentSort(array[i])
    return array
def tournamentSort(arr):
    tree = [None] * 2 * (len(arr) + len(arr) % 2)
    index = len(tree) - len(arr) - len(arr) % 2

    for i, v in enumerate(arr):
        tree[index + i] = (i, v)

    for j in range(len(arr)):
        n = len(arr)
        index = len(tree) - len(arr) - len(arr) % 2
        while index > -1:
            n = (n + 1) // 2
            for i in range(n):
                i = max(index + i * 2, 1)
                if tree[i] != None and tree[i + 1] != None:
                    if tree[i][1] < tree[i + 1][1]:
                        tree[i // 2] = tree[i]
                    else:
                        tree[i // 2] = tree[i + 1]
                else:
                    tree[i // 2] = tree[i] if tree[i] != None else tree[i + 1]
            index -= n
        index, x = tree[0]
        arr[j] = x
        tree[len(tree) - len(arr) - len(arr) % 2 + index] = None

# %%
def quicksort(alist, start, end):
    if end - start > 1:
        p = partition(alist, start, end)
        quicksort(alist, start, p)
        quicksort(alist, p + 1, end)
def partition(alist, start, end):
    pivot = alist[start]
    i = start + 1
    j = end - 1
    while True:
        while (i <= j and alist[i] <= pivot):
            i = i + 1
        while (i <= j and alist[j] >= pivot):
            j = j - 1
        if i <= j:
            alist[i], alist[j] = alist[j], alist[i]
        else:
            alist[start], alist[j] = alist[j], alist[start]
            return j
def fast(array):
    for line in range(len(array)):
        length = len(array[line])
        quicksort(array[line], 0, length)

# %%
def heapsort(alist):
    build_max_heap(alist)
    for i in range(len(alist) - 1, 0, -1):
        alist[0], alist[i] = alist[i], alist[0]
        max_heapify(alist, index=0, size=i)
def parent(i):
    return (i - 1) // 2
def left(i):
    return 2 * i + 1
def right(i):
    return 2 * i + 2
def build_max_heap(alist):
    length = len(alist)
    start = parent(length - 1)
    while start >= 0:
        max_heapify(alist, index=start, size=length)
        start = start - 1
def max_heapify(alist, index, size):
    l = left(index)
    r = right(index)
    if (l < size and alist[l] > alist[index]):
        largest = l
    else:
        largest = index
    if (r < size and alist[r] > alist[largest]):
        largest = r
    if (largest != index):
        alist[largest], alist[index] = alist[index], alist[largest]
        max_heapify(alist, largest, size)
def piramida(array):
    for line in range(len(array)):
        heapsort(array[line])

# %%
start = time.time()
sel = piramida(array)
print("Time of selection piramida: ", (time.time() - start)*1000)

start = time.time()
sel = vstavka(array)
print("Time of selection vstavka: ", (time.time() - start)*1000)

start = time.time()
sel = vibor(array)
print("Time of selection vibor: ", (time.time() - start)*1000)

start = time.time()
sel = obmen(array)
print("Time of selection obmen: ", (time.time() - start)*1000)

start = time.time()
sel = shella(array)
print("Time of selection shella: ", (time.time() - start)*1000)

start = time.time()
sel = TournamentSort(array)
print("Time of selection tournament: ", (time.time() - start)*1000)

start = time.time()
sel = fast(array)
print("Time of selection fast: ", (time.time() - start)*1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-237bad11e736> in <module>
#       1 start = time.time()
# ----> 2 sel = piramida(array)
#       3 print("Time of selection piramida: ", (time.time() - start)*1000)
#       4
#       5 start = time.time()
#
# NameError: name 'array' is not defined
